# %%
import numpy as np

# %%
x = np.linspace(-40,40,1000)

# %%
x.size
# Out:
# 1000

# %%
y = np.sin(x)

# %%
y.size
# Out:
# 1000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %matplotlib inline  -> to print the graph on screen

# %%
plt.plot(x,y)

# %%
y = x*x + 2*x + 6

# %%
plt.plot(x,y)
