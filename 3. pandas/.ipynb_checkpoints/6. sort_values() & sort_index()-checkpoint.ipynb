# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('matches.csv')

# %% [markdown]
# # sort_values():

# %%
# sorts rows based on the values

# %% [markdown]
# ### => On Series

# %%
myseries = data['team1'].value_counts() + data['team2'].value_counts()

# %%
myseries.sort_values(ascending=False)
# Out:
# Mumbai Indians                 157
# Royal Challengers Bangalore    152
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Delhi Daredevils               147
# Chennai Super Kings            131
# Rajasthan Royals               118
# Sunrisers Hyderabad             76
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# dtype: int64

# %%
# syntax -> 
# series => series.sort_values(ascending=True)
# dataframe => 
#dataframe.sort_values(['colA','colB'],ascending=[True,False],inplace=True)
#1st arguent can be a string or list - columns to base sort on
# 2nd argument - to decide the order of sorting
# inplace -> if True makes permenant changes on dataframe variable

# %% [markdown]
# ### => On DataFrames

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.sort_values('city',ascending=False,inplace=False)
# Out:
#       id  season           city        date                        team1  \
# 312  313    2012  Visakhapatnam  2012-04-07          Chennai Super Kings
# 622  623    2016  Visakhapatnam  2016-05-15               Mumbai Indians
# 615  616    2016  Visakhapatnam  2016-05-10          Sunrisers Hyderabad
# 612  613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 624  625    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# ..   ...     ...            ...         ...                          ...
# 466  467    2014            NaN  2014-04-23          Chennai Super Kings
# 468  469    2014            NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014            NaN  2014-04-25               Mumbai Indians
# 474  475    2014            NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014            NaN  2014-04-30          Sunrisers Hyderabad
#
#                        team2              toss_winner toss_decision  result  \
# ...

# %%
data.sort_values(['city','date'],ascending=[True,False])
# Out:
#       id  season       city        date                        team1  \
# 475  476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 459  460    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# ..   ...     ...        ...         ...                          ...
# 468  469    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014        NaN  2014-04-25               Mumbai Indians
# 466  467    2014        NaN  2014-04-23          Chennai Super Kings
# 461  462    2014        NaN  2014-04-19               Mumbai Indians
# 462  463    2014        NaN  2014-04-19        Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# # sort_index()

# %%
# sorts rows based on their index label

# %%
people_dict = {"weight": pd.Series([68, 83, 112],index=["alice","bob", "charles"]),
"birthyear": pd.Series([1984, 1985, 1992],index=["bob", "alice", "charles"], name="year"),
"children": pd.Series([0, 3], index=["charles","bob"]),
"hobby": pd.Series(["Biking", "Dancing"],index=["alice", "bob"]),}
people = pd.DataFrame(people_dict)

# %%
people["age"] = 2016 - people["birthyear"]
people["over 30"] = people["age"] > 30
people["pets"] = pd.Series({"bob": 0,"charles": 5,"eugene":1})
people.insert(1, "height", [172, 181, 185])
people = people.assign(body_mass_index = lambda df:df["weight"]/ (
    df["height"] / 100) ** 2).assign(overweight = lambda df:df["body_mass_index"] > 25)

# %%
people.sort_index(ascending=False)
# Out:
#          weight  height  birthyear  children    hobby  age  over 30  pets  \
# charles     112     185       1992       0.0      NaN   24    False   5.0
# bob          83     181       1984       3.0  Dancing   32     True   0.0
# alice        68     172       1985       NaN   Biking   31     True   NaN
#
#          body_mass_index  overweight
# charles        32.724617        True
# bob            25.335002        True
# alice          22.985398       False
