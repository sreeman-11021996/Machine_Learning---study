# %%
# matplotlib.image -> image class in matplotlib library

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
path = ('https://cloudxlab.s3.amazonaws.com/static/images/aha/matplotlib/introduction_image.png')

# %%
# imread() -> to read image from file - .png file

# %%
img = mpimg.imread(path)

# %%
# imshow() -> to display image

# %%
imgplot = plt.imshow(img)
